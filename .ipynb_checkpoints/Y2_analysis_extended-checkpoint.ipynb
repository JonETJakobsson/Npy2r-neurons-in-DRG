# %%
import scanpy as sc
import pandas as pd
import connectome as cn
import numpy as np
import networkx as nx
import holoviews as hv
from holoviews import opts

#Makes the text in figures editable in Illustrator
import matplotlib
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42

hv.notebook_extension()
hv.extension('matplotlib')
hv.output(fig="pdf")
# Out:
# <link rel="stylesheet" href="https://code.jquery.com/ui/1.10.4/themes/smoothness/jquery-ui.css">
# <style>div.hololayout {
#   display: flex;
#   align-items: center;
#   margin: 0;
# }
#
# div.holoframe {
#   width: 75%;
# }
#
# div.holowell {
#   display: flex;
#   align-items: center;
# }
#
# form.holoform {
#   background-color: #fafafa;
#   border-radius: 5px;
#   overflow: hidden;
#   padding-left: 0.8em;
#   padding-right: 0.8em;
#   padding-top: 0.4em;
#   padding-bottom: 0.4em;
#   box-shadow: inset 0 1px 1px rgba(0, 0, 0, 0.05);
#   margin-bottom: 20px;
#   border: 1px solid #e3e3e3;
# }
#
# div.holowidgets {
#   padding-right: 0;
#   width: 25%;
# }
#
# div.holoslider {
#   min-height: 0 !important;
#   height: 0.8em;
#   width: 100%;
# }
#
# div.holoformgroup {
#   padding-top: 0.5em;
#   margin-bottom: 0.5em;
# }
#
# div.hologroup {
#   padding-left: 0;
#   padding-right: 0.8em;
#   width: 100%;
# }
#
# .holoselect {
#   width: 92%;
#   margin-left: 0;
#   margin-right: 0;
# }
#
# .holotext {
#   padding-left:  0.5em;
#   padding-right: 0;
#   width: 100%;
# }
#
# .holowidgets .ui-resizable-se {
#   visibility: hidden
# }
#
# .holoframe > .ui-resizable-se {
#   visibility: hidden
# }
#
# .holowidgets .ui-resizable-s {
#   visibility: hidden
# }
#
#
# /* CSS rules for noUISlider based slider used by JupyterLab extension  */
#
# .noUi-handle {
#   width: 20px !important;
#   height: 20px !important;
#   left: -5px !important;
#   top: -5px !important;
# }
#
# .noUi-handle:before, .noUi-handle:after {
#   visibility: hidden;
#   height: 0px;
# }
#
# .noUi-target {
#   margin-left: 0.5em;
#   margin-right: 0.5em;
# }
# </style>
#
#
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#
#
#   <img src='...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
# </div>
# <link rel="stylesheet" href="https://code.jquery.com/ui/1.10.4/themes/smoothness/jquery-ui.css">
# <style>div.hololayout {
#   display: flex;
#   align-items: center;
#   margin: 0;
# }
#
# div.holoframe {
#   width: 75%;
# }
#
# div.holowell {
#   display: flex;
#   align-items: center;
# }
#
# form.holoform {
#   background-color: #fafafa;
#   border-radius: 5px;
#   overflow: hidden;
#   padding-left: 0.8em;
#   padding-right: 0.8em;
#   padding-top: 0.4em;
#   padding-bottom: 0.4em;
#   box-shadow: inset 0 1px 1px rgba(0, 0, 0, 0.05);
#   margin-bottom: 20px;
#   border: 1px solid #e3e3e3;
# }
#
# div.holowidgets {
#   padding-right: 0;
#   width: 25%;
# }
#
# div.holoslider {
#   min-height: 0 !important;
#   height: 0.8em;
#   width: 100%;
# }
#
# div.holoformgroup {
#   padding-top: 0.5em;
#   margin-bottom: 0.5em;
# }
#
# div.hologroup {
#   padding-left: 0;
#   padding-right: 0.8em;
#   width: 100%;
# }
#
# .holoselect {
#   width: 92%;
#   margin-left: 0;
#   margin-right: 0;
# }
#
# .holotext {
#   padding-left:  0.5em;
#   padding-right: 0;
#   width: 100%;
# }
#
# .holowidgets .ui-resizable-se {
#   visibility: hidden
# }
#
# .holoframe > .ui-resizable-se {
#   visibility: hidden
# }
#
# .holowidgets .ui-resizable-s {
#   visibility: hidden
# }
#
#
# /* CSS rules for noUISlider based slider used by JupyterLab extension  */
#
# .noUi-handle {
#   width: 20px !important;
#   height: 20px !important;
#   left: -5px !important;
#   top: -5px !important;
# }
#
# .noUi-handle:before, .noUi-handle:after {
#   visibility: hidden;
#   height: 0px;
# }
#
# .noUi-target {
#   margin-left: 0.5em;
#   margin-right: 0.5em;
# }
# </style>
#
#
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#
#
#   <img src='...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
# </div>

# %%
#Load Usoskin DRG data
uso_data = pd.read_csv("Data/RPM_table.csv",
                       index_col=0, sep=";", decimal=",")
uso = sc.AnnData(uso_data.values.T)
uso.obs_names = uso_data.columns
uso.var_names = uso_data.index

# Load Meta data
meta = pd.read_csv("Data/metadata_cells.csv",
                   sep=";", index_col="Sample ID")
uso.obs = meta
good_cells = ["NP1", 'TH', 'NF5', 'NF2', 'NF3',
              'NP2', 'PEP2', 'NF4', 'PEP1', 'NF1', 'NP3']
keep = [True if cell_type in good_cells else False for cell_type in uso.obs["Level 3"]]
drg_u = uso[keep]

#add annotation from Gatto et al.
gatto = {"NF1":"Aδ-LTMR",
         "NF2":"Aβ-LTMR",
         "NF3":"Aβ-LTMR",
         "NF4":"Proprioceptor",
         "NF5":"Proprioceptor",
         "PEP1":"C-nociceptor",
         "PEP2":"Aδ-nociceptor",
         "NP1":"Mechanical MrgprD",
         "NP2":"Itch MrgprA3",
         "NP3":"Itch Nppb",
         "TH":"C-LTMR",
        }

drg_u.obs["annotated"] = [gatto[k] for k in drg_u.obs["Level 3"]]

qc = sc.pp.calculate_qc_metrics(drg_u)
sc.pp.normalize_per_cell(drg_u, counts_per_cell_after=np.median(np.apply_over_axes(np.sum, drg_u.X, axes=1)))
sc.pp.log1p(drg_u)
print(f"Average: {qc[0]['n_genes_by_counts'].mean()}\nSd: {qc[0]['n_genes_by_counts'].std()}")

drg_u_s = sc.pp.scale(drg_u, copy=True)
# Out:
# Average: 3896.3810289389066
# Sd: 1879.0956773746475

# %%
# Load Zeisel DRG data
drg_z = sc.read_loom("Zeisel/l6_r3_peripheral_sensory_neurons.loom", sparse=False)
drg_z.var_names_make_unique()
drg_z.obs_names_make_unique()

#add annotation from Gatto et al.
gatto = {"PSNF1":"Aδ-LTMR",
         "PSNF2":"Aβ-LTMR",
         "PSNF3":"Proprioceptor",
         "PSPEP2":"C-nociceptor",
         "PSPEP3":"C-nociceptor",
         "PSPEP4":"C-nociceptor",
         "PSPEP5":"C-nociceptor",
         "PSPEP1":"Aδ-nociceptor",
         "PSNP2":"Mechanical MrgprD",
         "PSNP3":"Mechanical MrgprD",
         "PSNP4":"Itch MrgprA3",
         "PSNP5":"Itch MrgprA3",
         "PSNP6":"Itch Nppb",
         "PSNP1":"C-LTMR",
         "PSPEP6":"Cool",
         "PSPEP7":"Cool",
         "PSPEP8":"Cool"  
        }

drg_z.obs["annotated"] = [gatto[k] for k in drg_z.obs["ClusterName"]]


qc = sc.pp.calculate_qc_metrics(drg_z)
sc.pp.normalize_per_cell(drg_z, counts_per_cell_after=np.median(np.apply_over_axes(np.sum, drg_z.X, axes=1)))
sc.pp.log1p(drg_z)
print(f"Average: {qc[0]['n_genes_by_counts'].mean()}\nSd: {qc[0]['n_genes_by_counts'].std()}")

drg_z_s = sc.pp.scale(drg_z, copy=True)
# Out:
# Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.
# Average: 3449.2322784810126
# Sd: 964.6574579837637

# %%
# Load Li et al data
li_data = pd.read_csv("Data/GSE63576_DRG_neurons_RNA_Seq.txt.gz", sep = "\\t", index_col = 0)
drg_l = sc.AnnData(li_data.values.T)
drg_l.obs_names = li_data.columns
drg_l.var_names = li_data.index


qc = sc.pp.calculate_qc_metrics(drg_l)
sc.pp.normalize_per_cell(drg_l, counts_per_cell_after=np.median(np.apply_over_axes(np.sum, drg_l.X, axes=1)))
sc.pp.log1p(drg_l)
print(f"Average: {qc[0]['n_genes_by_counts'].mean()}\nSd: {qc[0]['n_genes_by_counts'].std()}")

drg_l_s = sc.pp.scale(drg_l, copy=True)
# Out:
# C:\Users\jonja158\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
# Average: 10853.960784313726
# Sd: 1326.0791231367332

# %%
merge_drg = drg_u_s.concatenate([drg_z_s, drg_l_s], batch_categories=["Usoskin", "Zeisel", "Li"], join="outer")
merge_drg.X = np.nan_to_num(merge_drg.X)
print((merge_drg.obs["batch"] == "Usoskin").sum(), "cells comes from Usoskin dataset")
print((merge_drg.obs["batch"] == "Zeisel").sum(), "cells comes from Zeisel dataset")
print((merge_drg.obs["batch"] == "Li").sum(), "cells comes from Li dataset")
# Out:
# 622 cells comes from Usoskin dataset
# 1580 cells comes from Zeisel dataset
# 204 cells comes from Li dataset

# %%
sc.tl.pca(merge_drg)
sc.pl.pca_scatter(merge_drg, color="batch")
# Out:
# ... storing 'Age' as categorical
# ... storing 'AnalysisPool' as categorical
# ... storing 'AnalysisProject' as categorical
# ... storing 'Bucket' as categorical
# ... storing 'CellConc' as categorical
# ... storing 'Cell_Conc' as categorical
# ... storing 'ChipID' as categorical
# ... storing 'Class' as categorical
# ... storing 'ClusterName' as categorical
# ... storing 'Comment' as categorical
# ... storing 'Comments' as categorical
# ... storing 'Content' as categorical
# ... storing 'DateCaptured' as categorical
# ... storing 'Date_Captured' as categorical
# ... storing 'Description' as categorical
# ... storing 'Developmental_compartment' as categorical
# ... storing 'DonorID' as categorical
# ... storing 'Estimated Number of Cells' as categorical
# ... storing 'Flowcell' as categorical
# ... storing 'Fraction Reads in Cells' as categorical
# ... storing 'Label' as categorical
# ... storing 'Level 1' as categorical
# ... storing 'Level 2' as categorical
# ... storing 'Level 3' as categorical
# ... storing 'Library' as categorical
# ... storing 'Location_based_on' as categorical
# ... storing 'Mean Reads per Cell' as categorical
# ... storing 'Median Genes per Cell' as categorical
# ... storing 'Median UMI Counts per Cell' as categorical
# ... storing 'NGI_PlateWell' as categorical
# ... storing 'Neurotransmitter' as categorical
# ... storing 'NumPooledAnimals' as categorical
# ... storing 'Num_Pooled_Animals' as categorical
# ... storing 'Number of Reads' as categorical
# ... storing 'PCRCycles' as categorical
# ... storing 'PCR_Cycles' as categorical
# ... storing 'PassedQC' as categorical
# ... storing 'Picking ToC' as categorical
# ... storing 'Picking sessions' as categorical
# ... storing 'PlugDate' as categorical
# ... storing 'Plug_Date' as categorical
# ... storing 'Probable_location' as categorical
# ... storing 'Project' as categorical
# ... storing 'Q30 Bases in Barcode' as categorical
# ... storing 'Q30 Bases in RNA Read' as categorical
# ... storing 'Q30 Bases in Sample Index' as categorical
# ... storing 'Q30 Bases in UMI' as categorical
# ... storing 'Reads Mapped Confidently to Exonic Regions' as categorical
# ... storing 'Reads Mapped Confidently to Intergenic Regions' as categorical
# ... storing 'Reads Mapped Confidently to Intronic Regions' as categorical
# ... storing 'Reads Mapped Confidently to Transcriptome' as categorical
# ... storing 'Region' as categorical
# ... storing 'SampleID' as categorical
# ... storing 'SampleIndex' as categorical
# ... storing 'SampleOK' as categorical
# ... storing 'Sample_Index' as categorical
# ... storing 'SeqComment' as categorical
# ... storing 'SeqLibDate' as categorical
# ... storing 'SeqLibOk' as categorical
# ... storing 'Seq_Comment' as categorical
# ... storing 'Seq_Lib_Date' as categorical
# ... storing 'Seq_Lib_Ok' as categorical
# ... storing 'Sequencing Saturation' as categorical
# ... storing 'Serial_Number' as categorical
# ... storing 'Sex' as categorical
# ... storing 'Species' as categorical
# ... storing 'Strain' as categorical
# ... storing 'Subclass' as categorical
# ... storing 'TargetNumCells' as categorical
# ... storing 'Target_Num_Cells' as categorical
# ... storing 'TaxonomyRank1' as categorical
# ... storing 'TaxonomyRank2' as categorical
# ... storing 'TaxonomyRank3' as categorical
# ... storing 'TaxonomyRank4' as categorical
# ... storing 'TaxonomySymbol' as categorical
# ... storing 'Taxonomy_group' as categorical
# ... storing 'TimepointPool' as categorical
# ... storing 'Tissue' as categorical
# ... storing 'Total Genes Detected' as categorical
# ... storing 'Transcriptome' as categorical
# ... storing 'Valid Barcodes' as categorical
# ... storing 'annotated' as categorical
# ... storing 'cDNAConcNanogramPerMicroliter' as categorical
# ... storing 'cDNALibOk' as categorical
# ... storing 'cDNA_Lib_Ok' as categorical
# ... storing 'ngperul_cDNA' as categorical
# ... storing 'Accession-Zeisel' as categorical

# %%
#filter HVG for Häring and Zeisel dataset
sc.pp.filter_genes_dispersion(drg_u, n_top_genes=5000)
sc.pp.filter_genes_dispersion(drg_z, n_top_genes=5000)
sc.pp.filter_genes_dispersion(drg_l, n_top_genes=5000)
#drg_u = cn.genecall.filter_genes(drg_u)
#drg_z = cn.genecall.filter_genes(drg_z)
#Merging using inner join will keep only varables that are incommon
merge_inner = drg_u.concatenate([drg_z, drg_l], batch_categories=["Usoskin", "Zeisel", "Li"], join="inner")
#makes a list of shared HVG to use for MNN correction
join_genes = list(merge_inner.var_names)
print(len(join_genes))
# Out:
# C:\Users\jonja158\AppData\Roaming\Python\Python36\site-packages\scanpy\preprocessing\_deprecated\highly_variable_genes.py:176: RuntimeWarning: invalid value encountered in greater_equal
#   gene_subset = df['dispersion_norm'].values >= disp_cut_off
# C:\Users\jonja158\AppData\Roaming\Python\Python36\site-packages\scanpy\preprocessing\_deprecated\highly_variable_genes.py:176: RuntimeWarning: invalid value encountered in greater_equal
#   gene_subset = df['dispersion_norm'].values >= disp_cut_off
# 920

# %%
#Runs the MNN using only shared HVG
mnn_drg = sc.external.pp.mnn_correct(drg_u_s[:,join_genes], drg_z_s[:,join_genes], drg_l_s[:,join_genes], batch_categories = ["Usoskin", "Zeisel", "Li"], k = 20, save_raw = True)[0]
# Out:
# Performing cosine normalization...
# Starting MNN correct iteration. Reference batch: 0
# Step 1 of 2: processing batch 1
#   Looking for MNNs...
#   Computing correction vectors...
#   Adjusting variance...
#   Applying correction...
# Step 2 of 2: processing batch 2
#   Looking for MNNs...
#   Computing correction vectors...
#   Adjusting variance...
#   Applying correction...
# MNN correction complete. Gathering output...
# Packing AnnData object...
# Done.

# %%
sc.tl.pca(mnn_drg)
sc.pl.pca(mnn_drg, color="batch")
# Out:
# ... storing 'Age' as categorical
# ... storing 'AnalysisPool' as categorical
# ... storing 'AnalysisProject' as categorical
# ... storing 'Bucket' as categorical
# ... storing 'CellConc' as categorical
# ... storing 'Cell_Conc' as categorical
# ... storing 'ChipID' as categorical
# ... storing 'Class' as categorical
# ... storing 'ClusterName' as categorical
# ... storing 'Comment' as categorical
# ... storing 'Comments' as categorical
# ... storing 'Content' as categorical
# ... storing 'DateCaptured' as categorical
# ... storing 'Date_Captured' as categorical
# ... storing 'Description' as categorical
# ... storing 'Developmental_compartment' as categorical
# ... storing 'DonorID' as categorical
# ... storing 'Estimated Number of Cells' as categorical
# ... storing 'Flowcell' as categorical
# ... storing 'Fraction Reads in Cells' as categorical
# ... storing 'Label' as categorical
# ... storing 'Level 1' as categorical
# ... storing 'Level 2' as categorical
# ... storing 'Level 3' as categorical
# ... storing 'Library' as categorical
# ... storing 'Location_based_on' as categorical
# ... storing 'Mean Reads per Cell' as categorical
# ... storing 'Median Genes per Cell' as categorical
# ... storing 'Median UMI Counts per Cell' as categorical
# ... storing 'NGI_PlateWell' as categorical
# ... storing 'Neurotransmitter' as categorical
# ... storing 'NumPooledAnimals' as categorical
# ... storing 'Num_Pooled_Animals' as categorical
# ... storing 'Number of Reads' as categorical
# ... storing 'PCRCycles' as categorical
# ... storing 'PCR_Cycles' as categorical
# ... storing 'PassedQC' as categorical
# ... storing 'Picking ToC' as categorical
# ... storing 'Picking sessions' as categorical
# ... storing 'PlugDate' as categorical
# ... storing 'Plug_Date' as categorical
# ... storing 'Probable_location' as categorical
# ... storing 'Project' as categorical
# ... storing 'Q30 Bases in Barcode' as categorical
# ... storing 'Q30 Bases in RNA Read' as categorical
# ... storing 'Q30 Bases in Sample Index' as categorical
# ... storing 'Q30 Bases in UMI' as categorical
# ... storing 'Reads Mapped Confidently to Exonic Regions' as categorical
# ... storing 'Reads Mapped Confidently to Intergenic Regions' as categorical
# ... storing 'Reads Mapped Confidently to Intronic Regions' as categorical
# ... storing 'Reads Mapped Confidently to Transcriptome' as categorical
# ... storing 'Region' as categorical
# ... storing 'SampleID' as categorical
# ... storing 'SampleIndex' as categorical
# ... storing 'SampleOK' as categorical
# ... storing 'Sample_Index' as categorical
# ... storing 'SeqComment' as categorical
# ... storing 'SeqLibDate' as categorical
# ... storing 'SeqLibOk' as categorical
# ... storing 'Seq_Comment' as categorical
# ... storing 'Seq_Lib_Date' as categorical
# ... storing 'Seq_Lib_Ok' as categorical
# ... storing 'Sequencing Saturation' as categorical
# ... storing 'Serial_Number' as categorical
# ... storing 'Sex' as categorical
# ... storing 'Species' as categorical
# ... storing 'Strain' as categorical
# ... storing 'Subclass' as categorical
# ... storing 'TargetNumCells' as categorical
# ... storing 'Target_Num_Cells' as categorical
# ... storing 'TaxonomyRank1' as categorical
# ... storing 'TaxonomyRank2' as categorical
# ... storing 'TaxonomyRank3' as categorical
# ... storing 'TaxonomyRank4' as categorical
# ... storing 'TaxonomySymbol' as categorical
# ... storing 'Taxonomy_group' as categorical
# ... storing 'TimepointPool' as categorical
# ... storing 'Tissue' as categorical
# ... storing 'Total Genes Detected' as categorical
# ... storing 'Transcriptome' as categorical
# ... storing 'Valid Barcodes' as categorical
# ... storing 'annotated' as categorical
# ... storing 'cDNAConcNanogramPerMicroliter' as categorical
# ... storing 'cDNALibOk' as categorical
# ... storing 'cDNA_Lib_Ok' as categorical
# ... storing 'ngperul_cDNA' as categorical

# %%
sc.pp.neighbors(mnn_drg, n_neighbors=15)
sc.tl.leiden(mnn_drg, resolution=1)
sc.tl.umap(mnn_drg, random_state=3)

# %%
import seaborn as sns
import matplotlib.colors


color = sns.palettes.color_palette("Dark2", n_colors=10, desat=0.5)

# %%
sc.pl.umap(mnn_drg, color=["annotated"], palette= color+["red"], alpha = 0.5)

# %%
sc.pl.umap(mnn_drg, color=["batch"], alpha = 0.5)

# %%
train_X = mnn_drg.X[mnn_drg.obs["batch"] != "Li", :]
train_y =mnn_drg.obs["annotated"][mnn_drg.obs["batch"] != "Li"].values
test_X =  mnn_drg.X[mnn_drg.obs["batch"] == "Li", :]

# %%
from sklearn.model_selection import cross_val_score
from sklearn.svm import LinearSVC
from sklearn.neighbors import KNeighborsClassifier

#evaluating linearSVC
clf_lsvm = LinearSVC(dual=False)
clf_lsvm.fit(train_X, train_y)
print(clf_lsvm.score(train_X, train_y))

#using cross_val_score to estimate the overfitting and accuracy (Not working 20180917)
#cross_val_score(estimator=clf_lsvm, X=train_X, y=train_y)

#evaluating Kneigbors
clf_knc = KNeighborsClassifier(n_neighbors=5)
clf_knc.fit(train_X, train_y)
print(clf_knc.score(train_X, train_y))
# Out:
# 1.0
# 0.9518619436875567

# %%
labels = clf_lsvm.predict(test_X)
#prob = clf_knc.predict_proba(mnn.X)
prob = clf_lsvm.decision_function(mnn_drg.X)
import numpy as np

prob = np.max(prob, axis = 1)

# %%
mnn_drg.obs["annotated"][mnn_drg.obs["batch"] == "Li"] = labels
mnn_drg.obs["probability"] = prob

# %%
sc.pl.umap(mnn_drg, color=["annotated"], palette=color, alpha = 0.5)
sc.pl.umap(mnn_drg, color=["probability"])
# Out:
# WARNING: Length of palette colors is smaller than the number of categories (palette length: 10, categories length: 11. Some categories will have the same color.

# %%
merge_drg.obs["annotated"] = mnn_drg.obs["annotated"]

# %%
# Distribution of cells from the two different datasets in the cell populations
data = merge_drg.obs.pivot_table( index = "batch", columns=["annotated"], values="n_counts", aggfunc=np.count_nonzero)
data = data.stack()
data = data.reset_index(name="counts")
#hv.Bars(data, kdims=["batch"], vdims=["Häring","Zeisel"])
hv.Bars(data, kdims=["annotated","batch"]).opts(hv.opts.Bars(stacked = True, xrotation=90, fig_size=(200)))
# Out:
# :Bars   [annotated,batch]   (counts)

# %%
#Here we ads some decoration to our plot to explain gene functions
var_names = ["Npy2r",
             "Sst",
             "Nppb",
             "Il31ra",
             "Osmr",
             "Cysltr2",
             "Plcb3",
             "Trpv1",
             "Trpa1",
             "Htr1f",
             "Htr2a",
             "Htr7",
             "Hrh1",
             "Hrh4",
             "Hrh3",
             "Mrgprx1",
             "Mrgpra3",
             "F2rl1"
             ]
vgl = ["Neuro peptides",
       "IL-31",
       "Leukotriene receptor",
       "Trp receptor/signaling",
       "Serotonin",
       "Histamin",
       "Mrgp receptor",
       "Par2"
      ]
vgp = [(1,2),
       (3,4),
       (5,5),
       (6,8),
       (9,11),
       (12,14),
       (15,16),
       (17,17)
      ]
sc.pl.dotplot(merge_drg, var_names=var_names, groupby="annotated", figsize=(10,6), dendrogram=True, var_group_labels=vgl, var_group_positions=vgp)
# Out:
# WARNING: Groups are not reordered because the `groupby` categories and the `var_group_labels` are different.
# categories: Aβ-LTMR, Aδ-LTMR, Aδ-nociceptor, etc.
# var_group_labels: Neuro peptides, IL-31, Leukotriene receptor, etc.
# GridSpec(2, 5, height_ratios=[0.5, 10], width_ratios=[8.25, 0.8, 0.2, 0.5, 0.25])

# %%
merge_drg.obs["annotated"].value_counts()
# Out:
# Mechanical MrgprD    526
# C-LTMR               526
# C-nociceptor         430
# Itch MrgprA3         177
# Itch Nppb            163
# Cool                 147
# Aβ-LTMR              139
# Aδ-nociceptor        131
# Proprioceptor         85
# Aδ-LTMR               82
# Name: annotated, dtype: int64

# %%
y2 = merge_drg[merge_drg[:,merge_drg.var_names == "Npy2r"].X > 0.01, :]

print(sum(y2.obs["batch"] == "Usoskin"), " cells comes from Usoskin et al")
print(sum(y2.obs["batch"] == "Zeisel"), " cells comes from Zeisel et al")
print(sum(y2.obs["batch"] == "Li"), " cells comes from Li et al")
# Out:
# 30  cells comes from Usoskin et al
# 180  cells comes from Zeisel et al
# 60  cells comes from Li et al

# %%
#Here we ads some decoration to our plot to explain gene functions
var_names = ["Npy2r",
             "Sst",
             "Nppb",
             "Il31ra",
             "Osmr",
             "Cysltr2",
             "Plcb3",
             "Trpv1",
             "Trpa1",
             "Htr1f",
             "Htr2a",
             "Htr7",
             "Hrh1",
             "Hrh4",
             "Hrh3",
             "Mrgprx1",
             "Mrgpra3",
             "F2rl1"
             ]
vgl = ["Neuro peptides",
       "IL-31",
       "Leukotriene receptor",
       "Trp receptor/signaling",
       "Serotonin",
       "Histamin",
       "Mrgp receptor",
       "Par2"
      ]
vgp = [(1,2),
       (3,4),
       (5,5),
       (6,8),
       (9,11),
       (12,14),
       (15,16),
       (17,17)
      ]
sc.pl.dotplot(y2, var_names=var_names, groupby="annotated",  figsize=(10,6), var_group_labels=vgl, var_group_positions=vgp)
# Out:
# GridSpec(2, 5, height_ratios=[0.5, 10], width_ratios=[9.05, 0, 0.2, 0.5, 0.25])

# %%
y2.obs["annotated"].value_counts()
# Out:
# Itch Nppb            147
# C-nociceptor          63
# Aδ-nociceptor         42
# C-LTMR                 5
# Aβ-LTMR                4
# Mechanical MrgprD      3
# Itch MrgprA3           3
# Proprioceptor          2
# Aδ-LTMR                1
# Name: annotated, dtype: int64
